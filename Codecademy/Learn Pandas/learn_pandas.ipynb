# %% [markdown]
# ### Import Library

# %%
import pandas as pd

# %% [markdown]
# ### Create DataFrame

# %%
df1 = pd.DataFrame(
    {
        "Product ID": [1, 2, 3, 4],
        "Product Name": ["t-shirt", "t-shirt", "skirt", "skirt"],
        "Color": ["blue", "green", "red", "black"],
    }
)
df1
# Out:
#    Product ID Product Name  Color
# 0           1      t-shirt   blue
# 1           2      t-shirt  green
# 2           3        skirt    red
# 3           4        skirt  black

# %%
df2 = pd.DataFrame(
    [
        [1, "San Diego", 100],
        [2, "Los Angeles", 120],
        [3, "San Francisco", 90],
        [4, "Sacramento", 115],
    ],
    columns=["Store ID", "Location", "Number of Employees"],
)

df2
# Out:
#    Store ID       Location  Number of Employees
# 0         1      San Diego                  100
# 1         2    Los Angeles                  120
# 2         3  San Francisco                   90
# 3         4     Sacramento                  115

# %% [markdown]
# ### Read CSV

# %%
df = pd.read_csv("Electric_Vehicle_Population_Data.csv")
df.head(3)
# Out:
#    VIN (1-10)   County       City State  Postal Code  Model Year      Make  \
# 0  2C4RC1N71H   Kitsap  Bremerton    WA      98311.0        2017  CHRYSLER
# 1  2C4RC1N7XL  Stevens   Colville    WA      99114.0        2020  CHRYSLER
# 2  KNDC3DLCXN   Yakima     Yakima    WA      98908.0        2022       KIA
#
#       Model                   Electric Vehicle Type  \
# 0  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
# 1  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
# 2       EV6          Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible              33
# 1            Clean Alternative Fuel Vehicle Eligible              32
# 2  Eligibility unknown as battery range has not b...               0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  23.0       349437882
# 1          0                   7.0       154690532
# 2          0                  14.0       219969144
#
#                   Vehicle Location        Electric Utility  2020 Census Tract
# 0  POINT (-122.6466274 47.6341188)  PUGET SOUND ENERGY INC       5.303509e+10
# 1     POINT (-117.90431 48.547075)             AVISTA CORP       5.306595e+10
# 2  POINT (-120.6027202 46.5965625)              PACIFICORP       5.307700e+10

# %% [markdown]
# ### Select Column

# %%
model_year = df["Model Year"]
type(model_year)
model_year.head()
# Out:
# 0    2017
# 1    2020
# 2    2022
# 3    2018
# 4    2018
# Name: Model Year, dtype: int64

# %% [markdown]
# ### Select Multiple Columns

# %%
model_and_range = df[["Model", "Electric Range"]]
model_and_range
type(model_and_range)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Select Rows

# %%
model_and_range.iloc[2]  # Select one row
# Out:
# Model             EV6
# Electric Range      0
# Name: 2, dtype: object

# %%
model_and_range.iloc[2:10]  # Select multiple row 2 to 10 (not including 10)
# Out:
#            Model  Electric Range
# 2            EV6               0
# 3        MODEL 3             215
# 4           LEAF             151
# 5           NIRO             239
# 6     COUNTRYMAN              12
# 7        MODEL Y               0
# 8  PRIUS PLUG-IN               6
# 9        MODEL 3               0

# %%
model_and_range.iloc[:4]  # Select multiple row start to 4 (not including 4)
# Out:
#       Model  Electric Range
# 0  PACIFICA              33
# 1  PACIFICA              32
# 2       EV6               0
# 3   MODEL 3             215

# %%
model_and_range.iloc[-3:]  # Select multiple row (last 3 rows)
# Out:
#           Model  Electric Range
# 159464     XC90              32
# 159465  MODEL 3             220
# 159466  MODEL Y               0

# %% [markdown]
# ### Select Rows with Logic

# %%
model3_df = model_and_range[model_and_range.Model == "MODEL 3"]
model3_df.head()
# Out:
#       Model  Electric Range
# 3   MODEL 3             215
# 9   MODEL 3               0
# 30  MODEL 3             322
# 35  MODEL 3             308
# 37  MODEL 3             215

# %%
range_greater_300 = model_and_range[
    (model_and_range["Electric Range"] > 300) & (model_and_range.Model != "MODEL 3")
]
range_greater_300.head()
# Out:
#         Model  Electric Range
# 241   MODEL S             330
# 714   MODEL S             330
# 773   MODEL S             330
# 1045  MODEL S             330
# 1666  MODEL S             330

# %%
range_less_300 = model_and_range[model_and_range["Electric Range"] < 300]
range_less_300.head()
# Out:
#       Model  Electric Range
# 0  PACIFICA              33
# 1  PACIFICA              32
# 2       EV6               0
# 3   MODEL 3             215
# 4      LEAF             151

# %%
tesla = df[(df.Make == "TESLA") | (df["Electric Range"] > 340)]
tesla.head()
# Out:
#     VIN (1-10)  County               City State  Postal Code  Model Year  \
# 3   5YJ3E1EA0J  Kitsap  Bainbridge Island    WA      98110.0        2018
# 7   7SAYGDEF8N  Yakima             Yakima    WA      98901.0        2022
# 9   5YJ3E1EB1M  Kitsap            Poulsbo    WA      98370.0        2021
# 14  5YJSA1E21J  Island            Clinton    WA      98236.0        2018
# 17  5YJSA1E21H  Chelan             Manson    WA      98831.0        2017
#
#      Make    Model           Electric Vehicle Type  \
# 3   TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 7   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 9   TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 14  TESLA  MODEL S  Battery Electric Vehicle (BEV)
# 17  TESLA  MODEL S  Battery Electric Vehicle (BEV)
#
#     Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 3             Clean Alternative Fuel Vehicle Eligible             215
# 7   Eligibility unknown as battery range has not b...               0
# 9   Eligibility unknown as battery range has not b...               0
# 14            Clean Alternative Fuel Vehicle Eligible             249
# 17            Clean Alternative Fuel Vehicle Eligible             210
#
#     Base MSRP  Legislative District  DOL Vehicle ID  \
# 3           0                  23.0       476786887
# 7           0                  15.0       207786505
# 9           0                  23.0       211699309
# 14          0                  10.0       476056199
# 17          0                  12.0       324336855
#
#                    Vehicle Location           Electric Utility  \
# 3   POINT (-122.5235781 47.6293323)     PUGET SOUND ENERGY INC
# 7       POINT (-120.500225 46.6043)                 PACIFICORP
# 9      POINT (-122.64177 47.737525)     PUGET SOUND ENERGY INC
# 14   POINT (-122.359364 47.9796552)     PUGET SOUND ENERGY INC
# 17      POINT (-120.1531 47.885505)  PUD NO 1 OF CHELAN COUNTY
#
#     2020 Census Tract
# 3        5.303509e+10
# 7        5.307700e+10
# 9        5.303594e+10
# 14       5.302997e+10
# 17       5.300796e+10

# %%
tesla_and_mercedes = df[df.Make.isin(["TESLA", "MERCEDES-BENZ"])]
tesla_and_mercedes.head()
# Out:
#     VIN (1-10)  County               City State  Postal Code  Model Year  \
# 3   5YJ3E1EA0J  Kitsap  Bainbridge Island    WA      98110.0        2018
# 7   7SAYGDEF8N  Yakima             Yakima    WA      98901.0        2022
# 9   5YJ3E1EB1M  Kitsap            Poulsbo    WA      98370.0        2021
# 14  5YJSA1E21J  Island            Clinton    WA      98236.0        2018
# 17  5YJSA1E21H  Chelan             Manson    WA      98831.0        2017
#
#      Make    Model           Electric Vehicle Type  \
# 3   TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 7   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 9   TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 14  TESLA  MODEL S  Battery Electric Vehicle (BEV)
# 17  TESLA  MODEL S  Battery Electric Vehicle (BEV)
#
#     Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 3             Clean Alternative Fuel Vehicle Eligible             215
# 7   Eligibility unknown as battery range has not b...               0
# 9   Eligibility unknown as battery range has not b...               0
# 14            Clean Alternative Fuel Vehicle Eligible             249
# 17            Clean Alternative Fuel Vehicle Eligible             210
#
#     Base MSRP  Legislative District  DOL Vehicle ID  \
# 3           0                  23.0       476786887
# 7           0                  15.0       207786505
# 9           0                  23.0       211699309
# 14          0                  10.0       476056199
# 17          0                  12.0       324336855
#
#                    Vehicle Location           Electric Utility  \
# 3   POINT (-122.5235781 47.6293323)     PUGET SOUND ENERGY INC
# 7       POINT (-120.500225 46.6043)                 PACIFICORP
# 9      POINT (-122.64177 47.737525)     PUGET SOUND ENERGY INC
# 14   POINT (-122.359364 47.9796552)     PUGET SOUND ENERGY INC
# 17      POINT (-120.1531 47.885505)  PUD NO 1 OF CHELAN COUNTY
#
#     2020 Census Tract
# 3        5.303509e+10
# 7        5.307700e+10
# 9        5.303594e+10
# 14       5.302997e+10
# 17       5.300796e+10

# %%
tesla_and_mercedes_reset_index = tesla_and_mercedes.reset_index(
    drop=True
)  # Drop module drops the extra column
tesla_and_mercedes_reset_index.head()
# Out:
#    VIN (1-10)  County               City State  Postal Code  Model Year  \
# 0  5YJ3E1EA0J  Kitsap  Bainbridge Island    WA      98110.0        2018
# 1  7SAYGDEF8N  Yakima             Yakima    WA      98901.0        2022
# 2  5YJ3E1EB1M  Kitsap            Poulsbo    WA      98370.0        2021
# 3  5YJSA1E21J  Island            Clinton    WA      98236.0        2018
# 4  5YJSA1E21H  Chelan             Manson    WA      98831.0        2017
#
#     Make    Model           Electric Vehicle Type  \
# 0  TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 1  TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 2  TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 3  TESLA  MODEL S  Battery Electric Vehicle (BEV)
# 4  TESLA  MODEL S  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             215
# 1  Eligibility unknown as battery range has not b...               0
# 2  Eligibility unknown as battery range has not b...               0
# 3            Clean Alternative Fuel Vehicle Eligible             249
# 4            Clean Alternative Fuel Vehicle Eligible             210
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  23.0       476786887
# 1          0                  15.0       207786505
# 2          0                  23.0       211699309
# 3          0                  10.0       476056199
# 4          0                  12.0       324336855
#
#                   Vehicle Location           Electric Utility  \
# 0  POINT (-122.5235781 47.6293323)     PUGET SOUND ENERGY INC
# 1      POINT (-120.500225 46.6043)                 PACIFICORP
# 2     POINT (-122.64177 47.737525)     PUGET SOUND ENERGY INC
# 3   POINT (-122.359364 47.9796552)     PUGET SOUND ENERGY INC
# 4      POINT (-120.1531 47.885505)  PUD NO 1 OF CHELAN COUNTY
#
#    2020 Census Tract
# 0       5.303509e+10
# 1       5.307700e+10
# 2       5.303594e+10
# 3       5.302997e+10
# 4       5.300796e+10
